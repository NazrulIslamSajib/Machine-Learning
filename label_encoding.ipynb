# %%
#label Encoding using sklearn
classes=['ClassA','ClassB','ClassC','ClassD']
instances=['ClassA','ClassB','ClassC','ClassD','ClassA','ClassB','ClassC','ClassD']

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
encoded_labels=label_encoder.fit_transform(instances)
encoded_labels
# Out:
# array([0, 1, 2, 3, 0, 1, 2, 3])

# %%
original_labels=label_encoder.inverse_transform(encoded_labels)
original_labels
# Out:
# array(['ClassA', 'ClassB', 'ClassC', 'ClassD', 'ClassA', 'ClassB',
#        'ClassC', 'ClassD'], dtype='<U6')

# %%
print("Encoded data : ",encoded_labels)
print("Decoded data : ",original_labels)
# Out:
# Encoded data :  [0 1 2 3 0 1 2 3]
# Decoded data :  ['ClassA' 'ClassB' 'ClassC' 'ClassD' 'ClassA' 'ClassB' 'ClassC' 'ClassD']
