# %%
import pandas as pd

# %%
df = pd.read_csv('linear_data.csv')

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
x=df['x']
x
# Out:
# 0       0.00000
# 1       0.02004
# 2       0.04008
# 3       0.06012
# 4       0.08016
#          ...
# 495     9.91984
# 496     9.93988
# 497     9.95992
# 498     9.97996
# 499    10.00000
# Name: x, Length: 500, dtype: float64

# %%
y=df['y']

y
# Out:
# 0       4.447692
# 1       5.024612
# 2       5.869593
# 3       4.722490
# 4       4.877101
#          ...
# 495    25.356174
# 496    24.417804
# 497    25.625916
# 498    24.269704
# 499    24.732043
# Name: y, Length: 500, dtype: float64

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
reg =LinearRegress
# Out:
# LinearRegression()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x.to_frame(),y,test_size=0.6,random_state=42)
accuracy=reg.score(X_test,y_test)*100
accuracy
#ekhane amar liniar regreasion dekhchi , then ami non liniar regression dekhbo dekhi ki rkm accuracy ase
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# 99.33984572945026

# %%
df1= pd.read_csv('nonlinear_data.csv')

# %%
import numpy as np
from sklearn.model_selection import train_test_split
x1=df1['x']
y1=df1['y']
from sklearn.linear_model import LinearRegression
reg1 =LinearRegression()
reg1.fit(x1.values.reshape(-1,1),y1)
X_train,X_test,y_train,y_test=train_test_split(x1.to_frame(),y1,test_size=0.6,random_state=42)
accuracy=reg.score(X_test,y_test)*100
accuracy
#dekho ekhane accuracy thik nai ulto -1 cole aschi tar mane eta liniar regression diye kora jabe na eigula korte hbe
#polynominal equation
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -14244.156304408

# %%
import matplotlib.pyplot as plt
plt.scatter(x1, y1, color='blue', label='Data with Linear Relationship')
plt.scatter(x,y,color='red',label='Data with linear')
plt.plot(x1.values.reshape(-1,1), reg1.predict(x1.values.reshape(-1,1)), color='black', label='Best fit line')
plt.plot(x.values.reshape(-1,1), reg.predict(x.values.reshape(-1,1)), color='green', label='Best fit line')

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=8) # polynomial regression with degree 2
X_poly = poly.fit_transform(x1.values.reshape(-1,1))
X_poly.shape
reg_poly = LinearRegression()
reg_poly.fit(X_poly, y1)
reg_poly.score(X_poly, y1)
# Out:
# 0.9950242593819496

# %%
plt.scatter(x1.values.reshape(-1,1), y1, color='green', label='Data with Non-linear Relationship')
plt.plot(x1.values.reshape(-1,1), 2 * np.sin(x1.values.reshape(-1,1)), color='orange', label='True Non-linear Relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Non-linear Relationship')
plt.legend()
